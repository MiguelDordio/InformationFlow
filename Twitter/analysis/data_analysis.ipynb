# %%
from Twitter.analysis.data_analysis import *
from os import walk

# %% [markdown]
# # Data Import and overview

# %%
DATASETS_PATH = "../../data/processed_tweets/"

processed_filenames = next(walk(DATASETS_PATH), (None, None, []))[2]
filenames = [DATASETS_PATH + "/" + filename for filename in processed_filenames]

# %%
df = ensemble_dataset(filenames)

# %% [markdown]
# ## Data characteristics

# %%
get_data_characteristics(df)
# Out:
# Data characteristics
# Average nº of tweets per day of the week: 227982
# Nº of tweets with known topics 557315 and are 34.92% of the data
# Nº of tweets do collect retweeters information: 64878
# 16.45% have retweets

# %%
df['year'].value_counts()
# Out:
# 2021    533375
# 2019    531272
# 2020    531227
# Name: year, dtype: int64

# %% [markdown]
# ## Tweets performance

# %%
topics_categories = df['topics_cleaned'].unique()[1:]
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
week_days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_phases = ['Morning', 'Afternoon', 'Dusk', 'Night', 'Middle of the night']
sentiments = ['Negative', 'Neutral', 'Positive']
hashtags = [True, False]
offline_graphs = False

# %%
tweet_analysis = df[['text', 'year', 'day_phase', 'day_of_week', 'month', 'retweet_count', 'quote_count', 'like_count', 'reply_count', 'sentiment', 'hashtags', 'topics_cleaned', 'reach']]

# %% [markdown]
# ### Average retweet and like count during the day

# %%
df_analysis = retweets_likes_info_by_year(tweet_analysis, ['day_phase'], day_phases)
df_analysis
# Out:
#    year            day_phase  count day_phase  % day_phase  % with retweets  \
# 0  2019              Morning           105912    19.935551            14.37
# 1  2019            Afternoon           106273    20.003501            17.78
# 2  2019                 Dusk           106415    20.030229            18.12
# 3  2019                Night           106312    20.010842            17.73
# 4  2019  Middle of the night           106360    20.019877            17.32
# 0  2020              Morning           105633    19.884720            13.95
# 1  2020            Afternoon           106420    20.032867            16.94
# 2  2020                 Dusk           106397    20.028538            16.95
# 3  2020                Night           106408    20.030608            16.73
# 4  2020  Middle of the night           106369    20.023267            16.44
# 0  2021              Morning           105994    19.872322            12.56
# 1  2021            Afternoon           106727    20.009749            17.36
# 2  2021                 Dusk           106852    20.033185            16.93
# 3  2021                Night           106796    20.022686            17.10
# 4  2021  Middle of the night           107006    20.062058            16.38
#
#    % with likes  retweets mean  likes mean
# 0         44.76           0.41        2.45
# 1         48.18           0.56        3.40
# 2         50.00           0.56        3.62
# 3         49.82           0.54        3.64
# 4         50.74           0.52        3.68
# 0         45.36           0.41        2.63
# 1         47.80           0.54        3.67
# 2         49.96           0.53        3.84
# 3         50.41           0.51        3.91
# 4         51.16           0.48        3.88
# 0         43.31           0.37        2.92
# 1         50.32           0.58        4.88
# 2         51.20           0.55        4.92
# 3         52.03           0.55        4.95
# 4         52.78           0.50        4.89

# %%
get_correlations_2_vars(df_analysis, 'retweets mean', 'likes mean')
# Out:
# Correlation between retweets mean and likes mean:
# pearson=0.69
# spearman=0.39
# kendall=0.20

# %%
analysis_chart(df_analysis, 'day_phase', '% with retweets', '% with likes', 'Day phase', '% with retweets', '% with likes', 'Percentage of retweets and likes during the day', offline_graphs)
analysis_chart(df_analysis, 'day_phase', 'retweets mean', 'likes mean', 'Day phase', 'Retweets mean', 'Likes mean', 'Average retweets and likes during the day', offline_graphs)

# %% [markdown]
# ### Average retweet and like count during the week

# %%
df_analysis = retweets_likes_info_by_year(tweet_analysis, ['day_of_week'], week_days)
df_analysis
# Out:
#    year day_of_week  count day_of_week  % day_of_week  % with retweets  \
# 0  2019      Monday              75745      14.257292            17.17
# 1  2019     Tuesday              77311      14.552056            17.41
# 2  2019   Wednesday              75810      14.269527            17.65
# 3  2019    Thursday              75831      14.273479            17.23
# 4  2019      Friday              74646      14.050430            17.12
# 5  2019    Saturday              76095      14.323172            16.62
# 6  2019      Sunday              75834      14.274044            16.24
# 0  2020      Monday              75439      14.200897            16.39
# 1  2020     Tuesday              75374      14.188661            16.45
# 2  2020   Wednesday              76868      14.469897            16.27
# 3  2020    Thursday              76952      14.485709            16.15
# 4  2020      Friday              75579      14.227251            16.35
# 5  2020    Saturday              75512      14.214639            16.11
# 6  2020      Sunday              75503      14.212945            15.72
# 0  2021      Monday              75841      14.219077            16.17
# 1  2021     Tuesday              75929      14.235575            16.34
# 2  2021   Wednesday              76012      14.251137            16.17
# 3  2021    Thursday              75965      14.242325            16.10
# 4  2021      Friday              77487      14.527678            16.37
# 5  2021    Saturday              76062      14.260511            16.08
# 6  2021      Sunday              76079      14.263698            15.26
#
#    % with likes  retweets mean  likes mean
# 0         48.71           0.53        3.33
# 1         48.80           0.53        3.30
# 2         49.10           0.55        3.40
# 3         48.65           0.55        3.35
# 4         48.64           0.50        3.30
# 5         48.85           0.49        3.44
# 6         48.16           0.49        3.39
# 0         48.86           0.52        3.60
# 1         48.44           0.49        3.50
# 2         48.87           0.49        3.49
# 3         48.64           0.48        3.49
# 4         49.32           0.48        3.57
# 5         49.53           0.49        3.78
# 6         48.96           0.49        3.68
# 0         49.36           0.51        4.44
# 1         49.65           0.52        4.36
# 2         49.85           0.53        4.43
# 3         49.60           0.51        4.41
# 4         50.40           0.54        4.63
# 5         50.76           0.49        4.71
# 6         49.94           0.47        4.60

# %%
get_correlations_2_vars(df_analysis, 'retweets mean', 'likes mean')
# Out:
# Correlation between retweets mean and likes mean:
# pearson=-0.04
# spearman=-0.19
# kendall=-0.11

# %%
analysis_chart(df_analysis, 'day_of_week', '% with retweets', '% with likes', 'Weekday', '% with retweets',
               '% with likes', 'Percentage of retweets and likes during the week', offline_graphs)
analysis_chart(df_analysis, 'day_of_week', 'retweets mean', 'likes mean', 'Weekday', 'Retweets mean', 'Likes mean',
               'Average retweets and likes during the week', offline_graphs)
# Out:
# <div>                            <div id="ae23fea5-8ed7-4a53-a216-f97358f902bb" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae23fea5-8ed7-4a53-a216-f97358f902bb")) {                    Plotly.newPlot(                        "ae23fea5-8ed7-4a53-a216-f97358f902bb",                        [{"marker":{"color":"#006D77"},"name":"% with retweets 2019","textposition":"inside","width":0.28,"x":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],"y":[17.17,17.41,17.65,17.23,17.12,16.62,16.24],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#E29578"},"name":"% with likes 2019","x":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],"y":[48.71,48.8,49.1,48.65,48.64,48.85,48.16],"type":"scatter","xaxis":"x","yaxis":"y2"},{"marker":{"color":"#FBD1A2"},"name":"% with retweets 2020","textposition":"inside","width":0.28,"x":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],"y":[16.39,16.45,16.27,16.15,16.35,16.11,15.72],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#254E70"},"name":"% with likes 2020","x":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],"y":[48.86,48.44,48.87,48.64,49.32,49.53,48.96],"type":"scatter","xaxis":"x","yaxis":"y2"},{"marker":{"color":"#7DCFB6"},"name":"% with retweets 2021","textposition":"inside","width":0.28,"x":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],"y":[16.17,16.34,16.17,16.1,16.37,16.08,15.26],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#C33C54"},"name":"% with likes 2021","x":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],"y":[49.36,49.65,49.85,49.6,50.4,50.76,49.94],"type":"scatter","xaxis":"x","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778," ...
# <div>                            <div id="9bfff598-8b98-4ce8-a831-97b97a18cb56" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9bfff598-8b98-4ce8-a831-97b97a18cb56")) {                    Plotly.newPlot(                        "9bfff598-8b98-4ce8-a831-97b97a18cb56",                        [{"marker":{"color":"#006D77"},"name":"Retweets mean 2019","textposition":"inside","width":0.28,"x":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],"y":[0.53,0.53,0.55,0.55,0.5,0.49,0.49],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#E29578"},"name":"Likes mean 2019","x":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],"y":[3.33,3.3,3.4,3.35,3.3,3.44,3.39],"type":"scatter","xaxis":"x","yaxis":"y2"},{"marker":{"color":"#FBD1A2"},"name":"Retweets mean 2020","textposition":"inside","width":0.28,"x":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],"y":[0.52,0.49,0.49,0.48,0.48,0.49,0.49],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#254E70"},"name":"Likes mean 2020","x":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],"y":[3.6,3.5,3.49,3.49,3.57,3.78,3.68],"type":"scatter","xaxis":"x","yaxis":"y2"},{"marker":{"color":"#7DCFB6"},"name":"Retweets mean 2021","textposition":"inside","width":0.28,"x":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],"y":[0.51,0.52,0.53,0.51,0.54,0.49,0.47],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#C33C54"},"name":"Likes mean 2021","x":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],"y":[4.44,4.36,4.43,4.41,4.63,4.71,4.6],"type":"scatter","xaxis":"x","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"] ...

# %% [markdown]
# ### Average retweet count per month

# %%
df_analysis = retweets_likes_info_by_year(tweet_analysis, ['month'], months)
df_analysis
# Out:
#     year      month  count month   % month  % with retweets  % with likes  \
# 0   2019    January        45257  8.518612            16.24         46.04
# 1   2019   February        40908  7.700011            16.79         48.17
# 2   2019      March        45287  8.524259            16.83         47.29
# 3   2019      April        43801  8.244553            17.28         48.78
# 4   2019        May        44208  8.321161            17.23         48.57
# 5   2019       June        43778  8.240223            16.89         48.14
# 6   2019       July        45211  8.509953            16.27         47.02
# 7   2019     August        45179  8.503930            17.09         49.70
# 8   2019  September        43741  8.233259            17.53         49.90
# 9   2019    October        45060  8.481531            17.69         50.22
# 10  2019   November        43706  8.226671            17.77         50.54
# 11  2019   December        45136  8.495836            17.19         50.12
# 0   2020    January        45117  8.492979            17.50         50.44
# 1   2020   February        42280  7.958933            18.08         50.98
# 2   2020      March        45167  8.502392            17.67         51.43
# 3   2020      April        43725  8.230945            16.83         50.54
# 4   2020        May        45038  8.478108            16.90         50.39
# 5   2020       June        43479  8.184637            17.64         48.52
# 6   2020       July        44979  8.467002            16.48         48.59
# 7   2020     August        44893  8.450813            15.92         48.06
# 8   2020  September        43503  8.189155            15.60         46.81
# 9   2020    October        44961  8.463613            15.34         46.91
# 10  2020   November        43411  8.171836            13.43         47.60
# 11  2020   December        44674  8.409588            13.09         47.06
# 0   2021    January        44756  8.391094            14.47         47.31
# 1   2021   February        40557  7.603843            15.67         48.81
# 2   2021      March        44925  8.422779            15.70         49.02
# 3   2021      April        43527  8.160675            15.41         48.50
# 4   2021        May        45145  8.464026            15.98         48.98
# 5   2021       June        43880  8.226857            16.02         48.78
# 6   2021       July        45351  8.502648            15.75         49.05
# 7   2021     August        45606  8.550457            16.28         50.20
# 8   2021  September        43978  8.245231            16.50         50.12
# 9   2021    October        45670  8.562456            16.93         51.92
# 10  2021   November        44280  8.301851            17.20         53.38
# 11  2021   December        45700  8.568081            16.88         52.95
#
#     retweets mean  likes mean
# 0            0.49        2.90
# 1            0.48        2.98
# 2            0.51        3.30
# 3            0.54        3.38
# 4            0.53        3.41
# 5            0.50        3.19
# 6            0.47        3.09
# 7            0.51        3.43
# 8            0.54        3.53
# 9            0.55        3.60
# 10           0.56        3.75
# 11           0.54        3.74
# 0            0.55        3.89
# 1            0.57        3.97
# 2            0.55        3.68
# 3            0.49        3.59
# 4            0.52        3.55
# 5            0.59        3.72
# 6            0.52        3.63
# 7            0.47        3.47
# 8            0.45        3.38
# 9            0.48        3.48
# 10           0.38        3.39
# 11           0.35        3.31
# 0            0.43        3.55
# 1            0.49        3.91
# 2            0.51        4.19
# 3            0.48        4.23
# 4            0.47        4.35
# 5            0.51        4.42
# 6            0.50        4.37
# 7            0.52        4.63
# 8            0.51        4.69
# 9            0.52        4.84
# 10           0.60        5.68
# 11           0.58        5.23

# %%
get_correlations_2_vars(df_analysis, 'retweets mean', 'likes mean')
# Out:
# Correlation between retweets mean and likes mean:
# pearson=0.43
# spearman=0.45
# kendall=0.33

# %%
analysis_chart(df_analysis, 'month', '% with retweets', '% with likes', 'Month', '% with retweets',
               '% with likes', 'Percentage of retweets and likes during the year', offline_graphs)
analysis_chart(df_analysis, 'month', 'retweets mean', 'likes mean', 'Month', 'Retweets mean', 'Likes mean',
               'Average retweets and likes during the year', offline_graphs)
# Out:
# <div>                            <div id="508550e3-1cc9-491a-a4bd-b3d034a07262" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("508550e3-1cc9-491a-a4bd-b3d034a07262")) {                    Plotly.newPlot(                        "508550e3-1cc9-491a-a4bd-b3d034a07262",                        [{"marker":{"color":"#006D77"},"name":"% with retweets 2019","textposition":"inside","width":0.28,"x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[16.24,16.79,16.83,17.28,17.23,16.89,16.27,17.09,17.53,17.69,17.77,17.19],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#E29578"},"name":"% with likes 2019","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[46.04,48.17,47.29,48.78,48.57,48.14,47.02,49.7,49.9,50.22,50.54,50.12],"type":"scatter","xaxis":"x","yaxis":"y2"},{"marker":{"color":"#FBD1A2"},"name":"% with retweets 2020","textposition":"inside","width":0.28,"x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[17.5,18.08,17.67,16.83,16.9,17.64,16.48,15.92,15.6,15.34,13.43,13.09],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#254E70"},"name":"% with likes 2020","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[50.44,50.98,51.43,50.54,50.39,48.52,48.59,48.06,46.81,46.91,47.6,47.06],"type":"scatter","xaxis":"x","yaxis":"y2"},{"marker":{"color":"#7DCFB6"},"name":"% with retweets 2021","textposition":"inside","width":0.28,"x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[14.47,15.67,15.7,15.41,15.98,16.02,15.75,16.28,16.5,16.93,17.2,16.88],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#C33C54"},"name":"% with likes 2021","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[47.31,48.81,49.02,48.5,48.98,48.78,49.05,50.2,50.12,51.92,53.38,52.95],"type":"scatter","xaxis":"x","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1 ...
# <div>                            <div id="39970ba1-4c9f-495d-bf2b-c0c6bd2a83a6" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("39970ba1-4c9f-495d-bf2b-c0c6bd2a83a6")) {                    Plotly.newPlot(                        "39970ba1-4c9f-495d-bf2b-c0c6bd2a83a6",                        [{"marker":{"color":"#006D77"},"name":"Retweets mean 2019","textposition":"inside","width":0.28,"x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[0.49,0.48,0.51,0.54,0.53,0.5,0.47,0.51,0.54,0.55,0.56,0.54],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#E29578"},"name":"Likes mean 2019","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[2.9,2.98,3.3,3.38,3.41,3.19,3.09,3.43,3.53,3.6,3.75,3.74],"type":"scatter","xaxis":"x","yaxis":"y2"},{"marker":{"color":"#FBD1A2"},"name":"Retweets mean 2020","textposition":"inside","width":0.28,"x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[0.55,0.57,0.55,0.49,0.52,0.59,0.52,0.47,0.45,0.48,0.38,0.35],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#254E70"},"name":"Likes mean 2020","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[3.89,3.97,3.68,3.59,3.55,3.72,3.63,3.47,3.38,3.48,3.39,3.31],"type":"scatter","xaxis":"x","yaxis":"y2"},{"marker":{"color":"#7DCFB6"},"name":"Retweets mean 2021","textposition":"inside","width":0.28,"x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[0.43,0.49,0.51,0.48,0.47,0.51,0.5,0.52,0.51,0.52,0.6,0.58],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#C33C54"},"name":"Likes mean 2021","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[3.55,3.91,4.19,4.23,4.35,4.42,4.37,4.63,4.69,4.84,5.68,5.23],"type":"scatter","xaxis":"x","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinew ...

# %% [markdown]
# ### Tweets performance by sentiment

# %%
df_analysis = retweets_likes_info_by_year(tweet_analysis, ['sentiment'], sentiments)
df_analysis
# Out:
#    year sentiment  count sentiment  % sentiment  % with retweets  \
# 0  2019  Negative           125989    23.714594            16.18
# 1  2019   Neutral           163721    30.816794            15.18
# 2  2019  Positive           241562    45.468611            18.80
# 0  2020  Negative           131147    24.687563            15.74
# 1  2020   Neutral           165832    31.216787            14.23
# 2  2020  Positive           234248    44.095650            17.86
# 0  2021  Negative           121368    22.754722            15.23
# 1  2021   Neutral           181050    33.944223            13.51
# 2  2021  Positive           230957    43.301055            18.52
#
#    % with likes  retweets mean  likes mean
# 0         46.80           0.52        2.90
# 1         44.15           0.42        2.80
# 2         52.78           0.59        3.98
# 0         48.13           0.50        3.15
# 1         43.83           0.40        2.98
# 2         53.02           0.55        4.26
# 0         48.73           0.50        3.83
# 1         43.54           0.40        3.73
# 2         55.59           0.60        5.48

# %%
get_correlations_2_vars(df_analysis, 'retweets mean', 'likes mean')
# Out:
# Correlation between retweets mean and likes mean:
# pearson=0.68
# spearman=0.67
# kendall=0.51

# %%
analysis_chart(df_analysis, 'sentiment', '% with retweets', '% with likes', 'Sentiment', 'Retweet count',
               'Likes count', 'Percentage of retweets and likes by sentiment', offline_graphs)
analysis_chart(df_analysis, 'sentiment', 'retweets mean', 'likes mean', 'Sentiment', 'Retweets mean', 'Likes mean',
               'Average retweets and likes number by sentiment', offline_graphs)
# Out:
# <div>                            <div id="13d9f79c-27e5-4e0f-84f5-f98cd957a8b1" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13d9f79c-27e5-4e0f-84f5-f98cd957a8b1")) {                    Plotly.newPlot(                        "13d9f79c-27e5-4e0f-84f5-f98cd957a8b1",                        [{"marker":{"color":"#006D77"},"name":"Retweet count 2019","textposition":"inside","width":0.28,"x":["Negative","Neutral","Positive"],"y":[16.18,15.18,18.8],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#E29578"},"name":"Likes count 2019","x":["Negative","Neutral","Positive"],"y":[46.8,44.15,52.78],"type":"scatter","xaxis":"x","yaxis":"y2"},{"marker":{"color":"#FBD1A2"},"name":"Retweet count 2020","textposition":"inside","width":0.28,"x":["Negative","Neutral","Positive"],"y":[15.74,14.23,17.86],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#254E70"},"name":"Likes count 2020","x":["Negative","Neutral","Positive"],"y":[48.13,43.83,53.02],"type":"scatter","xaxis":"x","yaxis":"y2"},{"marker":{"color":"#7DCFB6"},"name":"Retweet count 2021","textposition":"inside","width":0.28,"x":["Negative","Neutral","Positive"],"y":[15.23,13.51,18.52],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#C33C54"},"name":"Likes count 2021","x":["Negative","Neutral","Positive"],"y":[48.73,43.54,55.59],"type":"scatter","xaxis":"x","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888 ...
# <div>                            <div id="06bd2bbe-aa00-4124-953f-411a2b5f70b2" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06bd2bbe-aa00-4124-953f-411a2b5f70b2")) {                    Plotly.newPlot(                        "06bd2bbe-aa00-4124-953f-411a2b5f70b2",                        [{"marker":{"color":"#006D77"},"name":"Retweets mean 2019","textposition":"inside","width":0.28,"x":["Negative","Neutral","Positive"],"y":[0.52,0.42,0.59],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#E29578"},"name":"Likes mean 2019","x":["Negative","Neutral","Positive"],"y":[2.9,2.8,3.98],"type":"scatter","xaxis":"x","yaxis":"y2"},{"marker":{"color":"#FBD1A2"},"name":"Retweets mean 2020","textposition":"inside","width":0.28,"x":["Negative","Neutral","Positive"],"y":[0.5,0.4,0.55],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#254E70"},"name":"Likes mean 2020","x":["Negative","Neutral","Positive"],"y":[3.15,2.98,4.26],"type":"scatter","xaxis":"x","yaxis":"y2"},{"marker":{"color":"#7DCFB6"},"name":"Retweets mean 2021","textposition":"inside","width":0.28,"x":["Negative","Neutral","Positive"],"y":[0.5,0.4,0.6],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#C33C54"},"name":"Likes mean 2021","x":["Negative","Neutral","Positive"],"y":[3.83,3.73,5.48],"type":"scatter","xaxis":"x","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1 ...

# %% [markdown]
# ### Tweets performance by topics

# %% [markdown]
# #### Performance of each topic in retweets and likes

# %%
df_analysis = retweets_likes_info_by_year(tweet_analysis, ['topics_cleaned'], topics_categories)
df_analysis
# Out:
#     year        topics_cleaned  count topics_cleaned  % topics_cleaned  \
# 0   2019                 Other               32323.0         16.662457
# 1   2019                Person               36681.0         18.908999
# 2   2019         TV and Movies               34474.0         17.771294
# 3   2019              Entities               20770.0         10.706903
# 4   2019  Interest and Hobbies               26951.0         13.893199
# 5   2019                 Sport                7326.0          3.776542
# 6   2019                 Brand               29804.0         15.363916
# 7   2019                 Music                2036.0          1.049555
# 8   2019            Video Game                1985.0          1.023264
# 9   2019             Political                1428.0          0.736132
# 10  2019                  Book                 208.0          0.107224
# 11  2019               Holiday                   1.0          0.000515
# 12  2019                  News                   NaN               NaN
# 0   2020                 Other                1833.0          0.968714
# 1   2020                Person               47719.0         25.218793
# 2   2020         TV and Movies               27571.0         14.570870
# 3   2020              Entities               20310.0         10.733538
# 4   2020  Interest and Hobbies               28305.0         14.958778
# 5   2020                 Sport                6832.0          3.610612
# 6   2020                 Brand               29802.0         15.749921
# 7   2020                 Music                2075.0          1.096607
# 8   2020            Video Game                2482.0          1.311701
# 9   2020             Political                1777.0          0.939118
# 10  2020                  Book                 392.0          0.207166
# 11  2020               Holiday                5223.0          2.760279
# 12  2020                  News               14899.0          7.873903
# 0   2021                 Other                2445.0          1.404301
# 1   2021                Person               31365.0         18.014681
# 2   2021         TV and Movies               40400.0         23.203988
# 3   2021              Entities               16461.0          9.454477
# 4   2021  Interest and Hobbies               25651.0         14.732810
# 5   2021                 Sport                8498.0          4.880879
# 6   2021                 Brand               31725.0         18.221449
# 7   2021                 Music                1725.0          0.990764
# 8   2021            Video Game                2035.0          1.168815
# 9   2021             Political                1445.0          0.829945
# 10  2021                  Book                 327.0          0.187814
# 11  2021               Holiday                4712.0          2.706366
# 12  2021                  News                7319.0          4.203713
#
#     % with retweets  % with likes  retweets mean  likes mean
# 0             16.14         46.38           0.52        3.30
# 1             15.45         44.01           0.58        3.30
# 2             15.33         51.57           0.47        3.91
# 3             15.13         50.12           0.43        3.21
# 4             15.07         48.49           0.42        3.15
# 5             22.17         59.10           0.66        5.54
# 6             16.23         48.83           0.50        3.17
# 7             19.50         52.90           0.47        2.94
# 8             16.07         55.01           0.40        3.83
# 9             14.99         31.86           1.05        2.02
# 10            27.88         57.69           0.87        5.25
# 11              NaN        100.00           0.00       13.00
# 12              NaN           NaN            NaN         NaN
# 0             15.93         56.63           0.39        3.85
# 1             15.14         43.51           0.55        3.26
# 2             14.71         52.71           0.42        4.11
# 3             14.30         51.11           0.40        3.44
# 4             15.82         51.44           0.44        3.78
# 5             19.48         57.83           0.64        5.78
# 6             15.38         49.89           0.48        3.53
# 7             18.41         52.34           0.59        3.27
# 8             17.08         56.77           0.40        3.46
# 9             16.71         38.38           0.55        2.28
# 10            15.82         50.77           0.35        3.11
# 11            16.83         56.16           0.43        4.40
# 12            19.73         54.13           0.67        4.05
# 0             14.07         56.77           0.43        4.55
# 1             16.22         48.47           0.59        4.23
# 2             15.39         54.74           0.46        5.38
# 3             15.86         53.32           0.45        4.42
# 4             15.98         51.00           0.45        4.32
# 5             23.24         62.11           0.70        6.81
# 6             16.08         50.67           0.52        4.26
# 7             19.48         51.94           0.56        3.61
# 8             14.50         58.57           0.41        4.61
# 9             20.28         43.67           1.06        4.57
# 10            17.43         56.88           0.31        3.02
# 11            19.95         59.02           0.64        6.49
# 12            19.95         55.85           0.78        5.13

# %%
get_correlations_2_vars(df_analysis, 'retweets mean', 'likes mean')
# Out:
# Correlation between retweets mean and likes mean:
# pearson=-0.25
# spearman=0.22
# kendall=0.15

# %%
analysis_chart(df_analysis, 'topics_cleaned', '% with retweets', '% with likes', 'Topics', 'Retweet count',
               'Likes count', 'Percentage of retweets and likes by topic', offline_graphs)
analysis_chart(df_analysis, 'topics_cleaned', 'retweets mean', 'likes mean', 'Topics', 'Retweets mean', 'Likes mean',
               'Average tweets performance by topic', offline_graphs)
# Out:
# <div>                            <div id="62c9d4d2-23e1-448c-aa8f-b042efbeddda" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62c9d4d2-23e1-448c-aa8f-b042efbeddda")) {                    Plotly.newPlot(                        "62c9d4d2-23e1-448c-aa8f-b042efbeddda",                        [{"marker":{"color":"#006D77"},"name":"Retweet count 2019","textposition":"inside","width":0.28,"x":["Other","Person","TV and Movies","Entities","Interest and Hobbies","Sport","Brand","Music","Video Game","Political","Book","Holiday","News"],"y":[16.14,15.45,15.33,15.13,15.07,22.17,16.23,19.5,16.07,14.99,27.88,null,null],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#E29578"},"name":"Likes count 2019","x":["Other","Person","TV and Movies","Entities","Interest and Hobbies","Sport","Brand","Music","Video Game","Political","Book","Holiday","News"],"y":[46.38,44.01,51.57,50.12,48.49,59.1,48.83,52.9,55.01,31.86,57.69,100.0,null],"type":"scatter","xaxis":"x","yaxis":"y2"},{"marker":{"color":"#FBD1A2"},"name":"Retweet count 2020","textposition":"inside","width":0.28,"x":["Other","Person","TV and Movies","Entities","Interest and Hobbies","Sport","Brand","Music","Video Game","Political","Book","Holiday","News"],"y":[15.93,15.14,14.71,14.3,15.82,19.48,15.38,18.41,17.08,16.71,15.82,16.83,19.73],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#254E70"},"name":"Likes count 2020","x":["Other","Person","TV and Movies","Entities","Interest and Hobbies","Sport","Brand","Music","Video Game","Political","Book","Holiday","News"],"y":[56.63,43.51,52.71,51.11,51.44,57.83,49.89,52.34,56.77,38.38,50.77,56.16,54.13],"type":"scatter","xaxis":"x","yaxis":"y2"},{"marker":{"color":"#7DCFB6"},"name":"Retweet count 2021","textposition":"inside","width":0.28,"x":["Other","Person","TV and Movies","Entities","Interest and Hobbies","Sport","Brand","Music","Video Game","Political","Book","Holiday","News"],"y":[14.07,16.22,15.39,15.86,15.98,23.24,16.08,19.48,14.5,20.28,17.43,19.95,19.95],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#C33C54"},"name":"Likes count 2021","x":["Other","Person","TV and Movies","Entities","Interest and Hobbies","Sport","Brand","Music","Video Game","Political","Book","Holiday","News"],"y":[56.77,48.47,54.74,53.32,51.0,62.11,50.67,51.94,58.57,43.67,56.88,59.02,55.85],"type":"scatter","xaxis":"x","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222 ...
# <div>                            <div id="2b423b22-9cc3-4f9d-947a-b583fc355c00" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b423b22-9cc3-4f9d-947a-b583fc355c00")) {                    Plotly.newPlot(                        "2b423b22-9cc3-4f9d-947a-b583fc355c00",                        [{"marker":{"color":"#006D77"},"name":"Retweets mean 2019","textposition":"inside","width":0.28,"x":["Other","Person","TV and Movies","Entities","Interest and Hobbies","Sport","Brand","Music","Video Game","Political","Book","Holiday","News"],"y":[0.52,0.58,0.47,0.43,0.42,0.66,0.5,0.47,0.4,1.05,0.87,0.0,null],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#E29578"},"name":"Likes mean 2019","x":["Other","Person","TV and Movies","Entities","Interest and Hobbies","Sport","Brand","Music","Video Game","Political","Book","Holiday","News"],"y":[3.3,3.3,3.91,3.21,3.15,5.54,3.17,2.94,3.83,2.02,5.25,13.0,null],"type":"scatter","xaxis":"x","yaxis":"y2"},{"marker":{"color":"#FBD1A2"},"name":"Retweets mean 2020","textposition":"inside","width":0.28,"x":["Other","Person","TV and Movies","Entities","Interest and Hobbies","Sport","Brand","Music","Video Game","Political","Book","Holiday","News"],"y":[0.39,0.55,0.42,0.4,0.44,0.64,0.48,0.59,0.4,0.55,0.35,0.43,0.67],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#254E70"},"name":"Likes mean 2020","x":["Other","Person","TV and Movies","Entities","Interest and Hobbies","Sport","Brand","Music","Video Game","Political","Book","Holiday","News"],"y":[3.85,3.26,4.11,3.44,3.78,5.78,3.53,3.27,3.46,2.28,3.11,4.4,4.05],"type":"scatter","xaxis":"x","yaxis":"y2"},{"marker":{"color":"#7DCFB6"},"name":"Retweets mean 2021","textposition":"inside","width":0.28,"x":["Other","Person","TV and Movies","Entities","Interest and Hobbies","Sport","Brand","Music","Video Game","Political","Book","Holiday","News"],"y":[0.43,0.59,0.46,0.45,0.45,0.7,0.52,0.56,0.41,1.06,0.31,0.64,0.78],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#C33C54"},"name":"Likes mean 2021","x":["Other","Person","TV and Movies","Entities","Interest and Hobbies","Sport","Brand","Music","Video Game","Political","Book","Holiday","News"],"y":[4.55,4.23,5.38,4.42,4.32,6.81,4.26,3.61,4.61,4.57,3.02,6.49,5.13],"type":"scatter","xaxis":"x","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786" ...

# %% [markdown]
# #### Average tweet reach per topic

# %%
df_analysis = reach_by_topic(tweet_analysis, ['topics_cleaned'], topics_categories)
df_analysis
# Out:
#     year        topics_cleaned  count topics_cleaned  % topics_cleaned  \
# 0   2019                 Other               32323.0         16.662457
# 1   2019                Person               36681.0         18.908999
# 2   2019         TV and Movies               34474.0         17.771294
# 3   2019              Entities               20770.0         10.706903
# 4   2019  Interest and Hobbies               26951.0         13.893199
# 5   2019                 Sport                7326.0          3.776542
# 6   2019                 Brand               29804.0         15.363916
# 7   2019                 Music                2036.0          1.049555
# 8   2019            Video Game                1985.0          1.023264
# 9   2019             Political                1428.0          0.736132
# 10  2019                  Book                 208.0          0.107224
# 11  2019               Holiday                   1.0          0.000515
# 12  2019                  News                   NaN               NaN
# 0   2020                 Other                1833.0          0.968714
# 1   2020                Person               47719.0         25.218793
# 2   2020         TV and Movies               27571.0         14.570870
# 3   2020              Entities               20310.0         10.733538
# 4   2020  Interest and Hobbies               28305.0         14.958778
# 5   2020                 Sport                6832.0          3.610612
# 6   2020                 Brand               29802.0         15.749921
# 7   2020                 Music                2075.0          1.096607
# 8   2020            Video Game                2482.0          1.311701
# 9   2020             Political                1777.0          0.939118
# 10  2020                  Book                 392.0          0.207166
# 11  2020               Holiday                5223.0          2.760279
# 12  2020                  News               14899.0          7.873903
# 0   2021                 Other                2445.0          1.404301
# 1   2021                Person               31365.0         18.014681
# 2   2021         TV and Movies               40400.0         23.203988
# 3   2021              Entities               16461.0          9.454477
# 4   2021  Interest and Hobbies               25651.0         14.732810
# 5   2021                 Sport                8498.0          4.880879
# 6   2021                 Brand               31725.0         18.221449
# 7   2021                 Music                1725.0          0.990764
# 8   2021            Video Game                2035.0          1.168815
# 9   2021             Political                1445.0          0.829945
# 10  2021                  Book                 327.0          0.187814
# 11  2021               Holiday                4712.0          2.706366
# 12  2021                  News                7319.0          4.203713
#
#     reach mean
# 0      4423.33
# 1      4537.81
# 2      4498.50
# 3      3034.35
# 4      2992.07
# 5      4603.02
# 6      3822.88
# 7      3370.83
# 8      3029.05
# 9      4828.05
# 10     3814.84
# 11      764.00
# 12         NaN
# 0      2858.59
# 1      3813.11
# 2      4121.34
# 3      2969.26
# 4      3034.39
# 5      4478.53
# 6      3506.51
# 7      3834.58
# 8      2248.86
# 9      4040.92
# 10     2895.88
# 11     3342.00
# 12     4539.57
# 0      3076.23
# 1      4599.23
# 2      4744.92
# 3      3566.09
# 4      3441.15
# 5      4349.72
# 6      4462.90
# 7      3735.43
# 8      2785.09
# 9      4820.05
# 10     3764.52
# 11     5208.88
# 12     4861.35

# %%
multi_label_chart_v2(df_analysis, 'year', df_analysis['year'].unique(), 'year', 'reach mean', "Year", 'Reach mean', "topics_cleaned", 5, "group", 0.32,  'Average tweet reach by topic', offline_graphs)
# Out:
# <div>                            <div id="f7bd90d1-1045-4b58-be62-20308441ad7a" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7bd90d1-1045-4b58-be62-20308441ad7a")) {                    Plotly.newPlot(                        "f7bd90d1-1045-4b58-be62-20308441ad7a",                        [{"alignmentgroup":"True","hovertemplate":"year=%{x}<br>topics_cleaned=Other<br>reach mean=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":true,"text":[4423.33],"textposition":"auto","x":["2019"],"xaxis":"x11","y":[4423.33],"yaxis":"y11","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=%{x}<br>topics_cleaned=Person<br>reach mean=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[4537.81],"textposition":"auto","x":["2019"],"xaxis":"x12","y":[4537.81],"yaxis":"y12","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=%{x}<br>topics_cleaned=TV and Movies<br>reach mean=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[4498.5],"textposition":"auto","x":["2019"],"xaxis":"x13","y":[4498.5],"yaxis":"y13","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=%{x}<br>topics_cleaned=Entities<br>reach mean=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[3034.35],"textposition":"auto","x":["2019"],"xaxis":"x14","y":[3034.35],"yaxis":"y14","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=%{x}<br>topics_cleaned=Interest and Hobbies<br>reach mean=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[2992.07],"textposition":"auto","x":["2019"],"xaxis":"x15","y":[2992.07],"yaxis":"y15","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=%{x}<br>topics_cleaned=Sport<br>reach mean=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[4603.02],"textposition":"auto","x":["2019"],"xaxis":"x6","y":[4603.02],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=%{x}<br>topics_cleaned=Brand<br>reach mean=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[3822.88],"textposition":"auto","x":["2019"],"xaxis":"x7","y":[3822.88],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=%{x}<br>topics_cleaned=Music<br>reach mean=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[3370.83],"textposition":"auto","x":["2019"],"xaxis":"x8","y":[3370.83],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=%{x}<br>topics_cleaned=Video Game<br>reach mean=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[3029.05],"textposition":"auto","x":["2019"],"xaxis":"x9","y":[3029.05],"yaxis":"y9","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=%{x}<br>topics_cleaned=Political<br>reach mean=%{text}<extra></extra>","legendgroup":"2019","mar ...

# %%
multi_label_chart(df_analysis, 'topics_cleaned', topics_categories, 'topics_cleaned', 'reach mean', 'Topics', 'Reach mean', 'Average tweet reach by topic', offline_graphs)
# Out:
# <div>                            <div id="870de736-1ef2-43a5-8dd6-57b5402720ce" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("870de736-1ef2-43a5-8dd6-57b5402720ce")) {                    Plotly.newPlot(                        "870de736-1ef2-43a5-8dd6-57b5402720ce",                        [{"alignmentgroup":"True","hovertemplate":"topics_cleaned=%{x}<br>year=2019<br>reach mean=%{text}<extra></extra>","legendgroup":"Other","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"Other","offsetgroup":"Other","orientation":"v","showlegend":true,"text":[4423.33],"textposition":"auto","x":["Other"],"xaxis":"x","y":[4423.33],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=%{x}<br>year=2020<br>reach mean=%{text}<extra></extra>","legendgroup":"Other","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"Other","offsetgroup":"Other","orientation":"v","showlegend":false,"text":[2858.59],"textposition":"auto","x":["Other"],"xaxis":"x2","y":[2858.59],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=%{x}<br>year=2021<br>reach mean=%{text}<extra></extra>","legendgroup":"Other","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"Other","offsetgroup":"Other","orientation":"v","showlegend":false,"text":[3076.23],"textposition":"auto","x":["Other"],"xaxis":"x3","y":[3076.23],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=%{x}<br>year=2019<br>reach mean=%{text}<extra></extra>","legendgroup":"Person","marker":{"color":"#FBD1A2","pattern":{"shape":""}},"name":"Person","offsetgroup":"Person","orientation":"v","showlegend":true,"text":[4537.81],"textposition":"auto","x":["Person"],"xaxis":"x","y":[4537.81],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=%{x}<br>year=2020<br>reach mean=%{text}<extra></extra>","legendgroup":"Person","marker":{"color":"#FBD1A2","pattern":{"shape":""}},"name":"Person","offsetgroup":"Person","orientation":"v","showlegend":false,"text":[3813.11],"textposition":"auto","x":["Person"],"xaxis":"x2","y":[3813.11],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=%{x}<br>year=2021<br>reach mean=%{text}<extra></extra>","legendgroup":"Person","marker":{"color":"#FBD1A2","pattern":{"shape":""}},"name":"Person","offsetgroup":"Person","orientation":"v","showlegend":false,"text":[4599.23],"textposition":"auto","x":["Person"],"xaxis":"x3","y":[4599.23],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=%{x}<br>year=2019<br>reach mean=%{text}<extra></extra>","legendgroup":"TV and Movies","marker":{"color":"#7DCFB6","pattern":{"shape":""}},"name":"TV and Movies","offsetgroup":"TV and Movies","orientation":"v","showlegend":true,"text":[4498.5],"textposition":"auto","x":["TV and Movies"],"xaxis":"x","y":[4498.5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=%{x}<br>year=2020<br>reach mean=%{text}<extra></extra>","legendgroup":"TV and Movies","marker":{"color":"#7DCFB6","pattern":{"shape":""}},"name":"TV and Movies","offsetgroup":"TV and Movies","orientation":"v","showlegend":false,"text":[4121.34],"textposition":"auto","x":["TV and Movies"],"xaxis":"x2","y":[4121.34],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=%{x}<br>year=2021<br>reach mean=%{text}<extra></extra>","legendgroup":"TV and Movies","marker":{"color":"#7DCFB6","pattern":{"shape":""}},"name":"TV and Movies","offsetgroup":"TV and Movies","orientation":"v","showlegend":false,"text":[4744.92],"textposition":"auto","x":["TV and Movies"],"xaxis":"x3","y":[4744.92],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=% ...

# %% [markdown]
# #### Average retweet count per topic during the day

# %%
df_analysis = retweets_likes_info_by_year(tweet_analysis, ['day_phase', 'topics_cleaned'], day_phases)
df_analysis.head(60)
# Out:
#     year            day_phase        topics_cleaned  count day_phase  \
# 0   2019            Afternoon                  Book               32
# 1   2019            Afternoon                 Brand             6028
# 2   2019            Afternoon              Entities             4331
# 3   2019            Afternoon  Interest and Hobbies             5915
# 4   2019            Afternoon                 Music              383
# 5   2019            Afternoon                 Other             7761
# 6   2019            Afternoon                Person             8588
# 7   2019            Afternoon             Political              395
# 8   2019            Afternoon                 Sport             1335
# 9   2019            Afternoon         TV and Movies             5238
# 10  2019            Afternoon            Video Game              300
# 11  2019                 Dusk                  Book               63
# 12  2019                 Dusk                 Brand             6276
# 13  2019                 Dusk              Entities             4520
# 14  2019                 Dusk  Interest and Hobbies             5826
# 15  2019                 Dusk                 Music              422
# 16  2019                 Dusk                 Other             7131
# 17  2019                 Dusk                Person             7546
# 18  2019                 Dusk             Political              313
# 19  2019                 Dusk                 Sport             1483
# 20  2019                 Dusk         TV and Movies             6675
# 21  2019                 Dusk            Video Game              383
# 22  2019  Middle of the night                  Book               36
# 23  2019  Middle of the night                 Brand             5860
# 24  2019  Middle of the night              Entities             4246
# 25  2019  Middle of the night  Interest and Hobbies             4877
# 26  2019  Middle of the night                 Music              382
# 27  2019  Middle of the night                 Other             6175
# 28  2019  Middle of the night                Person             6773
# 29  2019  Middle of the night             Political              262
# 30  2019  Middle of the night                 Sport             2189
# 31  2019  Middle of the night         TV and Movies            11163
# 32  2019  Middle of the night            Video Game              393
# 33  2019              Morning                  Book               28
# 34  2019              Morning                 Brand             5552
# 35  2019              Morning              Entities             3195
# 36  2019              Morning  Interest and Hobbies             4191
# 37  2019              Morning                 Music              444
# 38  2019              Morning                 Other             4707
# 39  2019              Morning                Person             6174
# 40  2019              Morning             Political              186
# 41  2019              Morning                 Sport              554
# 42  2019              Morning         TV and Movies             4103
# 43  2019              Morning            Video Game              499
# 44  2019                Night                  Book               49
# 45  2019                Night                 Brand             6088
# 46  2019                Night              Entities             4478
# 47  2019                Night               Holiday                1
# 48  2019                Night  Interest and Hobbies             6142
# 49  2019                Night                 Music              405
# 50  2019                Night                 Other             6549
# 51  2019                Night                Person             7600
# 52  2019                Night             Political              272
# 53  2019                Night                 Sport             1765
# 54  2019                Night         TV and Movies             7295
# 55  2019                Night            Video Game              410
# 0   2020            Afternoon                  Book               91
# 1   2020            Afternoon                 Brand             6142
# 2   2020            Afternoon              Entities             4091
# 3   2020            Afternoon               Holiday             1303
#
#     % day_phase  % with retweets  % with likes  retweets mean  likes mean
# 0      0.016496            37.50         59.38           1.12        8.09
# 1      3.107425            17.47         48.59           0.49        3.13
# 2      2.232624            16.37         50.13           0.50        3.28
# 3      3.049173            16.04         48.45           0.49        3.34
# 4      0.197436            21.41         48.56           0.48        2.92
# 5      4.000784            17.60         46.40           0.51        3.27
# 6      4.427101            15.80         42.23           0.55        3.27
# 7      0.203622            14.18         30.89           1.06        2.77
# 8      0.688190            26.59         62.32           0.85        7.02
# 9      2.700181            18.00         53.53           0.60        4.38
# 10     0.154650            16.00         54.67           0.66        4.06
# 11     0.032476            41.27         71.43           1.65        7.25
# 12     3.235268            17.14         49.06           0.50        3.23
# 13     2.330053            16.77         49.85           0.50        3.47
# 14     3.003294            15.96         49.86           0.43        3.30
# 15     0.217540            22.27         56.64           0.55        2.84
# 16     3.676020            17.07         48.56           0.60        3.46
# 17     3.889951            16.15         45.97           0.62        3.43
# 18     0.161351            15.97         34.50           2.31        2.02
# 19     0.764484            22.18         58.60           0.64        5.52
# 20     3.440952            15.55         52.87           0.52        4.46
# 21     0.197436            14.62         57.96           0.44        4.27
# 22     0.018558            16.67         50.00           0.36        2.06
# 23     3.020821            15.92         50.00           0.55        3.43
# 24     2.188806            13.94         50.09           0.34        2.97
# 25     2.514086            15.58         51.18           0.46        3.29
# 26     0.196920            18.06         52.09           0.55        2.99
# 27     3.183203            14.87         46.57           0.53        3.52
# 28     3.491471            15.78         45.83           0.55        3.50
# 29     0.135061            12.60         29.01           0.48        1.63
# 30     1.128426            19.83         58.66           0.61        4.98
# 31     5.754509            14.06         51.48           0.40        3.59
# 32     0.202591            14.50         52.67           0.33        3.90
# 33     0.014434            10.71         39.29           0.29        1.39
# 34     2.862047            13.54         46.15           0.34        2.42
# 35     1.647018            12.33         49.30           0.29        2.42
# 36     2.160454            12.79         48.29           0.34        2.66
# 37     0.228881            18.47         52.70           0.33        2.51
# 38     2.426451            13.43         42.11           0.43        2.88
# 39     3.182687            12.52         40.80           0.48        2.50
# 40     0.095883            15.59         29.57           0.52        1.47
# 41     0.285586            18.59         53.61           0.54        4.29
# 42     2.115090            13.58         48.11           0.36        2.78
# 43     0.257234            16.43         53.31           0.31        3.87
# 44     0.025259            22.45         55.10           0.41        5.37
# 45     3.138355            16.82         50.15           0.62        3.60
# 46     2.308402            15.39         51.00           0.47        3.67
# 47     0.000515            14.44        100.00           0.00       13.00
# 48     3.166192            17.28         45.23           0.39        3.03
# 49     0.208777            16.55         54.07           0.45        3.48
# 50     3.375999            16.46         46.85           0.48        3.25
# 51     3.917788            16.91         45.05           0.70        3.67
# 52     0.140216            22.83         34.56           0.50        1.68
# 53     0.909855            16.13         59.38           0.65        5.54
# 54     3.760561            18.54         51.03           0.52        4.17
# 55     0.211354              NaN         56.83           0.34        3.17
# 0      0.048092            12.09         48.35           0.19        2.20
# 1      3.245957            16.59         48.21           0.50        3.74
# 2      2.162034            15.57         51.14           0.42        3.24
# 3      0.688616            18.57         56.79           0.53        4.95

# %%
multi_label_chart_v2(df_analysis, 'year', day_phases, 'day_phase', '% with retweets', "Day phase", "% with retweets", "topics_cleaned", 5, "group", 0.45,  "Percentage of retweets by topic during the day", offline_graphs)
# Out:
# <div>                            <div id="08b77703-af97-4918-a660-dcd094ee81fd" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08b77703-af97-4918-a660-dcd094ee81fd")) {                    Plotly.newPlot(                        "08b77703-af97-4918-a660-dcd094ee81fd",                        [{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Book<br>day_phase=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":true,"text":[37.5,41.27,16.67,10.71,22.45],"textposition":"auto","x":["Afternoon","Dusk","Middle of the night","Morning","Night"],"xaxis":"x11","y":[37.5,41.27,16.67,10.71,22.45],"yaxis":"y11","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Brand<br>day_phase=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[17.47,17.14,15.92,13.54,16.82],"textposition":"auto","x":["Afternoon","Dusk","Middle of the night","Morning","Night"],"xaxis":"x12","y":[17.47,17.14,15.92,13.54,16.82],"yaxis":"y12","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Entities<br>day_phase=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[16.37,16.77,13.94,12.33,15.39],"textposition":"auto","x":["Afternoon","Dusk","Middle of the night","Morning","Night"],"xaxis":"x13","y":[16.37,16.77,13.94,12.33,15.39],"yaxis":"y13","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Interest and Hobbies<br>day_phase=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[16.04,15.96,15.58,12.79,17.28],"textposition":"auto","x":["Afternoon","Dusk","Middle of the night","Morning","Night"],"xaxis":"x14","y":[16.04,15.96,15.58,12.79,17.28],"yaxis":"y14","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Music<br>day_phase=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[21.41,22.27,18.06,18.47,16.55],"textposition":"auto","x":["Afternoon","Dusk","Middle of the night","Morning","Night"],"xaxis":"x15","y":[21.41,22.27,18.06,18.47,16.55],"yaxis":"y15","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Other<br>day_phase=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[17.6,17.07,14.87,13.43,16.46],"textposition":"auto","x":["Afternoon","Dusk","Middle of the night","Morning","Night"],"xaxis":"x6","y":[17.6,17.07,14.87,13.43,16.46],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Person<br>day_phase=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[15.8,16.15,15.78,12.52,16.91],"textposition":"auto","x":["Afternoon","Dusk","Middle of the night","Morning","Night"],"xaxis":"x7","y":[15.8,16.15,15.78,12.52,16.91],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>top ...

# %%
multi_label_chart(df_analysis, "topics_cleaned", day_phases, "day_phase", "% with retweets", "Day phase", "% with retweets", "Percentage of retweets by topic during the day", offline_graphs)
# Out:
# <div>                            <div id="b98b9284-d95c-487d-abcc-a5e337582840" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b98b9284-d95c-487d-abcc-a5e337582840")) {                    Plotly.newPlot(                        "b98b9284-d95c-487d-abcc-a5e337582840",                        [{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Book<br>year=2019<br>day_phase=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Book","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"Book","offsetgroup":"Book","orientation":"v","showlegend":true,"text":[37.5,41.27,16.67,10.71,22.45],"textposition":"auto","x":["Afternoon","Dusk","Middle of the night","Morning","Night"],"xaxis":"x","y":[37.5,41.27,16.67,10.71,22.45],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Book<br>year=2020<br>day_phase=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Book","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"Book","offsetgroup":"Book","orientation":"v","showlegend":false,"text":[12.09,15.66,16.67,18.0,17.78],"textposition":"auto","x":["Afternoon","Dusk","Middle of the night","Morning","Night"],"xaxis":"x2","y":[12.09,15.66,16.67,18.0,17.78],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Book<br>year=2021<br>day_phase=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Book","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"Book","offsetgroup":"Book","orientation":"v","showlegend":false,"text":[22.58,17.72,17.24,14.81,14.86],"textposition":"auto","x":["Afternoon","Dusk","Middle of the night","Morning","Night"],"xaxis":"x3","y":[22.58,17.72,17.24,14.81,14.86],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Brand<br>year=2019<br>day_phase=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Brand","marker":{"color":"#FBD1A2","pattern":{"shape":""}},"name":"Brand","offsetgroup":"Brand","orientation":"v","showlegend":true,"text":[17.47,17.14,15.92,13.54,16.82],"textposition":"auto","x":["Afternoon","Dusk","Middle of the night","Morning","Night"],"xaxis":"x","y":[17.47,17.14,15.92,13.54,16.82],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Brand<br>year=2020<br>day_phase=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Brand","marker":{"color":"#FBD1A2","pattern":{"shape":""}},"name":"Brand","offsetgroup":"Brand","orientation":"v","showlegend":false,"text":[16.59,15.78,15.45,12.57,16.25],"textposition":"auto","x":["Afternoon","Dusk","Middle of the night","Morning","Night"],"xaxis":"x2","y":[16.59,15.78,15.45,12.57,16.25],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Brand<br>year=2021<br>day_phase=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Brand","marker":{"color":"#FBD1A2","pattern":{"shape":""}},"name":"Brand","offsetgroup":"Brand","orientation":"v","showlegend":false,"text":[17.57,17.11,15.37,13.03,16.92],"textposition":"auto","x":["Afternoon","Dusk","Middle of the night","Morning","Night"],"xaxis":"x3","y":[17.57,17.11,15.37,13.03,16.92],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Entities<br>year=2019<br>day_phase=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Entities","marker":{"color":"#7DCFB6","pattern":{"shape":""}},"name":"Entities","offsetgroup":"Entities","orientation":"v","showlegend":true,"text":[16.37,16.77,13.94,12.33,15.39],"textposition":"auto","x":["Afternoon","Dusk","Middle of the night","Morning","Night"],"xaxis":"x","y":[16.37,16.77,13.94,12.33,15.39],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Entities<br>ye ...

# %% [markdown]
# #### Average retweet count per topic during the week

# %%
df_analysis = retweets_likes_info_by_year(tweet_analysis, ['day_of_week', 'topics_cleaned'], week_days)
df_analysis
# Out:
#     year day_of_week        topics_cleaned  count day_of_week  % day_of_week  \
# 0   2019      Friday                  Book                 30       0.015465
# 1   2019      Friday                 Brand               4227       2.179012
# 2   2019      Friday              Entities               2987       1.539794
# 3   2019      Friday  Interest and Hobbies               3863       1.991371
# 4   2019      Friday                 Music                347       0.178878
# ..   ...         ...                   ...                ...            ...
# 86  2021   Wednesday                Person               4851       2.786202
# 87  2021   Wednesday             Political                243       0.139569
# 88  2021   Wednesday                 Sport               1083       0.622028
# 89  2021   Wednesday         TV and Movies               5374       3.086590
# 90  2021   Wednesday            Video Game                276       0.158522
#
#     % with retweets  % with likes  retweets mean  likes mean
# 0             20.00         56.67           0.20        2.77
# 1             16.63         48.78           0.50        3.23
# 2             15.03         49.15           0.40        3.21
# 3             13.72         47.04           0.40        2.96
# 4             15.56         49.28           0.26        1.88
# ..              ...           ...            ...         ...
# 86            16.47         48.34           0.62        4.32
# 87            20.99         44.86           1.40        4.97
# 88            25.58         63.80           0.79        7.53
# 89            15.41         54.82           0.52        5.67
# 90            13.77         61.59           0.35        4.99
#
# [260 rows x 9 columns]

# %%
multi_label_chart_v2(df_analysis, 'year', week_days, "day_of_week", '% with retweets', "Weekdays", "% with retweets", "topics_cleaned", 4, "group", 0.32, "Percentage of retweets by topic during the week", offline_graphs)
# Out:
# <div>                            <div id="85f5b185-f882-4f4c-b2fc-04ed2afa1c66" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85f5b185-f882-4f4c-b2fc-04ed2afa1c66")) {                    Plotly.newPlot(                        "85f5b185-f882-4f4c-b2fc-04ed2afa1c66",                        [{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Book<br>day_of_week=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":true,"text":[20.0,30.0,33.33,30.77,16.66,17.14,16.46],"textposition":"auto","x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x13","y":[20.0,30.0,33.33,30.77,16.66,17.14,16.46],"yaxis":"y13","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Brand<br>day_of_week=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[16.63,15.69,16.04,14.75,16.32,14.68,15.72],"textposition":"auto","x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x14","y":[16.63,15.69,16.04,14.75,16.32,14.68,15.72],"yaxis":"y14","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Entities<br>day_of_week=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[15.03,15.88,14.3,13.97,15.42,15.86,15.6],"textposition":"auto","x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x15","y":[15.03,15.88,14.3,13.97,15.42,15.86,15.6],"yaxis":"y15","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Interest and Hobbies<br>day_of_week=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[13.72,15.94,14.24,17.12,25.29,21.68,20.44],"textposition":"auto","x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x16","y":[13.72,15.94,14.24,17.12,25.29,21.68,20.44],"yaxis":"y16","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Music<br>day_of_week=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[15.56,18.55,18.98,14.7,16.6,16.44,16.3],"textposition":"auto","x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x9","y":[15.56,18.55,18.98,14.7,16.6,16.44,16.3],"yaxis":"y9","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Other<br>day_of_week=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[17.03,17.49,14.38,15.42,15.04,15.28,16.04],"textposition":"auto","x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x10","y":[17.03,17.49,14.38,15.42,15.04,15.28,16.04],"yaxis":"y10","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Person<br>day_of_week=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[15.57,15.83,14.96,13.66,17.24, ...

# %%
multi_label_chart(df_analysis, "topics_cleaned", week_days, "day_of_week", "% with retweets", "Weekday", "% with retweets", "Percentage of retweets by topic during the week", offline_graphs)
# Out:
# <div>                            <div id="ba54aa41-992f-46b4-ba06-517186698305" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba54aa41-992f-46b4-ba06-517186698305")) {                    Plotly.newPlot(                        "ba54aa41-992f-46b4-ba06-517186698305",                        [{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Book<br>year=2019<br>day_of_week=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Book","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"Book","offsetgroup":"Book","orientation":"v","showlegend":true,"text":[20.0,30.0,33.33,30.77,16.66,17.14,16.46],"textposition":"auto","x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x","y":[20.0,30.0,33.33,30.77,16.66,17.14,16.46],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Book<br>year=2020<br>day_of_week=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Book","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"Book","offsetgroup":"Book","orientation":"v","showlegend":false,"text":[16.33,16.95,20.75,10.71,15.25,17.54,13.56],"textposition":"auto","x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x2","y":[16.33,16.95,20.75,10.71,15.25,17.54,13.56],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Book<br>year=2021<br>day_of_week=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Book","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"Book","offsetgroup":"Book","orientation":"v","showlegend":false,"text":[16.33,20.59,18.18,24.44,20.0,11.29,13.95],"textposition":"auto","x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x3","y":[16.33,20.59,18.18,24.44,20.0,11.29,13.95],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Brand<br>year=2019<br>day_of_week=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Brand","marker":{"color":"#FBD1A2","pattern":{"shape":""}},"name":"Brand","offsetgroup":"Brand","orientation":"v","showlegend":true,"text":[16.63,15.69,16.04,14.75,16.32,14.68,15.72],"textposition":"auto","x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x","y":[16.63,15.69,16.04,14.75,16.32,14.68,15.72],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Brand<br>year=2020<br>day_of_week=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Brand","marker":{"color":"#FBD1A2","pattern":{"shape":""}},"name":"Brand","offsetgroup":"Brand","orientation":"v","showlegend":false,"text":[15.16,15.87,15.2,14.79,15.59,16.23,14.8],"textposition":"auto","x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x2","y":[15.16,15.87,15.2,14.79,15.59,16.23,14.8],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Brand<br>year=2021<br>day_of_week=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Brand","marker":{"color":"#FBD1A2","pattern":{"shape":""}},"name":"Brand","offsetgroup":"Brand","orientation":"v","showlegend":false,"text":[17.19,16.58,14.67,14.88,16.06,16.77,16.1],"textposition":"auto","x":["Friday","Monday","Saturday","Sunday","Thursday","Tuesday","Wednesday"],"xaxis":"x3","y":[17.19,16.58,14.67,14.88,16.06,16.77,16.1],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Entities<br>year=2019<br>day_of_week=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Entities","marker":{"color":"#7DCFB6","pattern":{"shape":""}},"name":"Entities","offsetgroup":"Entities","orientation":"v","showlegend":true,"text":[15.03,15.88,14.3,13.97,15.42,15.86,15.6], ...

# %% [markdown]
# #### Average retweet count per topic during the year

# %%
df_analysis = retweets_likes_info_by_year(tweet_analysis, ['month', 'topics_cleaned'], months)
df_analysis
# Out:
#      year      month        topics_cleaned  count month   % month  \
# 0    2019      April                  Book           24  0.012372
# 1    2019      April                 Brand         2303  1.187193
# 2    2019      April              Entities         1490  0.768093
# 3    2019      April  Interest and Hobbies         2183  1.125333
# 4    2019      April                 Music          174  0.089697
# ..    ...        ...                   ...          ...       ...
# 151  2021  September                Person         2535  1.455993
# 152  2021  September             Political          118  0.067774
# 153  2021  September                 Sport          545  0.313024
# 154  2021  September         TV and Movies         4022  2.310060
# 155  2021  September            Video Game          171  0.098215
#
#      % with retweets  % with likes  retweets mean  likes mean
# 0              37.50         58.33           1.96        8.12
# 1              15.59         47.37           0.41        3.08
# 2              15.64         49.93           0.36        2.85
# 3              16.31         47.82           0.42        3.06
# 4              24.14         55.75           0.53        3.22
# ..               ...           ...            ...         ...
# 151            17.16         49.31           0.58        4.36
# 152            22.03         42.37           0.82        2.72
# 153            24.22         59.27           0.57        5.83
# 154            15.61         54.18           0.49        5.74
# 155            16.37         60.23           0.52        4.91
#
# [445 rows x 9 columns]

# %%
multi_label_chart_v2(df_analysis, 'year', months, "month", '% with retweets', "Months", "% with retweets", "topics_cleaned", 4, "group", 0.32, "Percentage of retweets by topic during the year", offline_graphs)
# Out:
# <div>                            <div id="25f905ef-ef09-4b70-aa00-597de682d021" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25f905ef-ef09-4b70-aa00-597de682d021")) {                    Plotly.newPlot(                        "25f905ef-ef09-4b70-aa00-597de682d021",                        [{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Book<br>month=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":true,"text":[37.5,11.11,29.41,29.41,15.43,15.29,16.6,16.38,15.25,17.42,17.97,15.36],"textposition":"auto","x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x13","y":[37.5,11.11,29.41,29.41,15.43,15.29,16.6,16.38,15.25,17.42,17.97,15.36],"yaxis":"y13","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Brand<br>month=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[15.59,16.6,15.86,16.87,14.35,14.32,16.35,14.58,15.91,15.08,15.89,15.08],"textposition":"auto","x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x14","y":[15.59,16.6,15.86,16.87,14.35,14.32,16.35,14.58,15.91,15.08,15.89,15.08],"yaxis":"y14","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Entities<br>month=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[15.64,14.64,13.52,16.28,13.61,14.32,14.91,12.47,15.12,16.52,15.16,16.7],"textposition":"auto","x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x15","y":[15.64,14.64,13.52,16.28,13.61,14.32,14.91,12.47,15.12,16.52,15.16,16.7],"yaxis":"y15","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Interest and Hobbies<br>month=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[16.31,14.47,15.67,16.67,20.13,19.59,20.09,16.33,20.69,16.89,19.02,17.37],"textposition":"auto","x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x16","y":[16.31,14.47,15.67,16.67,20.13,19.59,20.09,16.33,20.69,16.89,19.02,17.37],"yaxis":"y16","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Music<br>month=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[24.14,18.44,23.28,16.14,14.76,16.92,15.24,15.33,15.32,17.99,17.5,19.21],"textposition":"auto","x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x9","y":[24.14,18.44,23.28,16.14,14.76,16.92,15.24,15.33,15.32,17.99,17.5,19.21],"yaxis":"y9","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Other<br>month=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[15.97,18.92,17.41,13.77,14.08,15.44,15.18,14.52,16.4,16.61,15.97,16.08],"textposition":"auto ...

# %%
multi_label_chart(df_analysis, "topics_cleaned", months, "month", "% with retweets", "Months", "% with retweets", "Percentage of retweets by topic during the year", offline_graphs)
# Out:
# <div>                            <div id="7547327c-a143-4587-8bc6-2c1f29bbaa60" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7547327c-a143-4587-8bc6-2c1f29bbaa60")) {                    Plotly.newPlot(                        "7547327c-a143-4587-8bc6-2c1f29bbaa60",                        [{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Book<br>year=2019<br>month=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Book","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"Book","offsetgroup":"Book","orientation":"v","showlegend":true,"text":[37.5,11.11,29.41,29.41,15.43,15.29,16.6,16.38,15.25,17.42,17.97,15.36],"textposition":"auto","x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x","y":[37.5,11.11,29.41,29.41,15.43,15.29,16.6,16.38,15.25,17.42,17.97,15.36],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Book<br>year=2020<br>month=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Book","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"Book","offsetgroup":"Book","orientation":"v","showlegend":false,"text":[22.22,13.56,10.0,45.0,7.69,11.11,17.31,20.0,26.67,3.7,7.89,17.07],"textposition":"auto","x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x2","y":[22.22,13.56,10.0,45.0,7.69,11.11,17.31,20.0,26.67,3.7,7.89,17.07],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Book<br>year=2021<br>month=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Book","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"Book","offsetgroup":"Book","orientation":"v","showlegend":false,"text":[19.23,31.03,20.0,20.59,17.07,8.0,26.32,10.34,4.17,20.0,10.71,22.22],"textposition":"auto","x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x3","y":[19.23,31.03,20.0,20.59,17.07,8.0,26.32,10.34,4.17,20.0,10.71,22.22],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Brand<br>year=2019<br>month=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Brand","marker":{"color":"#FBD1A2","pattern":{"shape":""}},"name":"Brand","offsetgroup":"Brand","orientation":"v","showlegend":true,"text":[15.59,16.6,15.86,16.87,14.35,14.32,16.35,14.58,15.91,15.08,15.89,15.08],"textposition":"auto","x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x","y":[15.59,16.6,15.86,16.87,14.35,14.32,16.35,14.58,15.91,15.08,15.89,15.08],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Brand<br>year=2020<br>month=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Brand","marker":{"color":"#FBD1A2","pattern":{"shape":""}},"name":"Brand","offsetgroup":"Brand","orientation":"v","showlegend":false,"text":[16.9,16.21,12.26,15.85,16.43,14.96,15.32,16.79,17.05,13.88,14.92,13.93],"textposition":"auto","x":["April","August","December","February","January","July","June","March","May","November","October","September"],"xaxis":"x2","y":[16.9,16.21,12.26,15.85,16.43,14.96,15.32,16.79,17.05,13.88,14.92,13.93],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Brand<br>year=2021<br>month=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Brand","marker":{"color":"#FBD1A2","pattern":{"shape":""}},"name":"Brand","offsetgroup":"Brand","orientation":"v","showlegend":false,"text":[15.62,15.38,16.93,15.11,14.9,14.89,15.38,16.41,16.59,16.63,17.42,17.24],"textposition":"auto","x":["April","August","December","February", ...

# %% [markdown]
# #### Impact of hashtags in topic popularity

# %%
df_analysis = retweets_likes_info_by_year(tweet_analysis, ['hashtags', 'topics_cleaned'], hashtags)
df_analysis
# Out:
#     year  hashtags        topics_cleaned  count hashtags  % hashtags  \
# 0   2019     False                  Book             131    0.067530
# 1   2019     False                 Brand           23448   12.087408
# 2   2019     False              Entities           15986    8.240758
# 3   2019     False  Interest and Hobbies           18669    9.623841
# 4   2019     False                 Music            1394    0.718605
# ..   ...       ...                   ...             ...         ...
# 21  2021      True                Person            4843    2.781607
# 22  2021      True             Political             250    0.143589
# 23  2021      True                 Sport            2896    1.663335
# 24  2021      True         TV and Movies           14448    8.298298
# 25  2021      True            Video Game             496    0.284881
#
#     % with retweets  % with likes  retweets mean  likes mean
# 0             24.43         58.78           0.68        6.40
# 1             15.09         49.17           0.46        3.09
# 2             14.14         50.78           0.39        3.14
# 3             14.95         52.38           0.43        3.42
# 4             19.15         54.23           0.50        3.49
# ..              ...           ...            ...         ...
# 21            24.45         52.84           0.98        5.23
# 22            29.20         46.80           1.22        4.33
# 23            26.66         63.36           0.92        8.05
# 24            18.77         58.02           0.59        6.29
# 25            21.37         61.29           0.77        5.97
#
# [75 rows x 9 columns]

# %%
multi_label_chart_v2(df_analysis, 'year', hashtags, "hashtags", '% with retweets', "Hashtags", "% with retweets", "topics_cleaned", 5, "group", 0.32, "Hashtags presence by topic and corresponding % retweet count", offline_graphs)
# Out:
# <div>                            <div id="6a5ceda7-7c5d-4370-be39-c3b4903d4474" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a5ceda7-7c5d-4370-be39-c3b4903d4474")) {                    Plotly.newPlot(                        "6a5ceda7-7c5d-4370-be39-c3b4903d4474",                        [{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Book<br>hashtags=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":true,"text":[24.43,33.77],"textposition":"auto","x":[false,true],"xaxis":"x11","y":[24.43,33.77],"yaxis":"y11","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Brand<br>hashtags=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[15.09,20.44],"textposition":"auto","x":[false,true],"xaxis":"x12","y":[15.09,20.44],"yaxis":"y12","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Entities<br>hashtags=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[14.14,18.42],"textposition":"auto","x":[false,true],"xaxis":"x13","y":[14.14,18.42],"yaxis":"y13","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Interest and Hobbies<br>hashtags=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[14.95,20.25],"textposition":"auto","x":[false,true],"xaxis":"x14","y":[14.95,20.25],"yaxis":"y14","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Music<br>hashtags=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[19.15,19.08],"textposition":"auto","x":[false,true],"xaxis":"x15","y":[19.15,19.08],"yaxis":"y15","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Other<br>hashtags=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[14.34,24.01],"textposition":"auto","x":[false,true],"xaxis":"x6","y":[14.34,24.01],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Person<br>hashtags=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[13.81,23.9],"textposition":"auto","x":[false,true],"xaxis":"x7","y":[13.81,23.9],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Political<br>hashtags=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[13.08,25.97],"textposition":"auto","x":[false,true],"xaxis":"x8","y":[13.08,25.97],"yaxis":"y8","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Sport<br>hashtags=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","o ...

# %%
multi_label_chart(df_analysis, "topics_cleaned", topics_categories, "hashtags", "% with retweets", "hashtags", "% with retweets", "Hashtags presence by topic and corresponding % retweet count", offline_graphs)
# Out:
# <div>                            <div id="51006c89-f917-4ba4-ab6a-26710b315655" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51006c89-f917-4ba4-ab6a-26710b315655")) {                    Plotly.newPlot(                        "51006c89-f917-4ba4-ab6a-26710b315655",                        [{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Book<br>year=2019<br>hashtags=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Book","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"Book","offsetgroup":"Book","orientation":"v","showlegend":true,"text":[24.43,33.77],"textposition":"auto","x":[false,true],"xaxis":"x","y":[24.43,33.77],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Book<br>year=2020<br>hashtags=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Book","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"Book","offsetgroup":"Book","orientation":"v","showlegend":false,"text":[12.08,27.66],"textposition":"auto","x":[false,true],"xaxis":"x2","y":[12.08,27.66],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Book<br>year=2021<br>hashtags=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Book","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"Book","offsetgroup":"Book","orientation":"v","showlegend":false,"text":[13.83,29.73],"textposition":"auto","x":[false,true],"xaxis":"x3","y":[13.83,29.73],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Brand<br>year=2019<br>hashtags=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Brand","marker":{"color":"#FBD1A2","pattern":{"shape":""}},"name":"Brand","offsetgroup":"Brand","orientation":"v","showlegend":true,"text":[15.09,20.44],"textposition":"auto","x":[false,true],"xaxis":"x","y":[15.09,20.44],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Brand<br>year=2020<br>hashtags=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Brand","marker":{"color":"#FBD1A2","pattern":{"shape":""}},"name":"Brand","offsetgroup":"Brand","orientation":"v","showlegend":false,"text":[14.17,20.63],"textposition":"auto","x":[false,true],"xaxis":"x2","y":[14.17,20.63],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Brand<br>year=2021<br>hashtags=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Brand","marker":{"color":"#FBD1A2","pattern":{"shape":""}},"name":"Brand","offsetgroup":"Brand","orientation":"v","showlegend":false,"text":[14.22,21.97],"textposition":"auto","x":[false,true],"xaxis":"x3","y":[14.22,21.97],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Entities<br>year=2019<br>hashtags=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Entities","marker":{"color":"#7DCFB6","pattern":{"shape":""}},"name":"Entities","offsetgroup":"Entities","orientation":"v","showlegend":true,"text":[14.14,18.42],"textposition":"auto","x":[false,true],"xaxis":"x","y":[14.14,18.42],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Entities<br>year=2020<br>hashtags=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Entities","marker":{"color":"#7DCFB6","pattern":{"shape":""}},"name":"Entities","offsetgroup":"Entities","orientation":"v","showlegend":false,"text":[13.1,18.83],"textposition":"auto","x":[false,true],"xaxis":"x2","y":[13.1,18.83],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Entities<br>year=2021<br>hashtags=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Entities","marker":{"color":"#7DCFB6","pattern":{"shape":""}},"name":"Entities","offsetgroup":"E ...

# %% [markdown]
# #### Tweet sentiment per topic

# %%
df_analysis = retweets_likes_info_by_year(tweet_analysis, ['sentiment', 'topics_cleaned'], sentiments)
df_analysis
# Out:
#     year sentiment        topics_cleaned  count sentiment  % sentiment  \
# 0   2019  Negative                  Book               44     0.022682
# 1   2019  Negative                 Brand             6595     3.399712
# 2   2019  Negative              Entities             4063     2.094470
# 3   2019  Negative  Interest and Hobbies             5987     3.086289
# 4   2019  Negative                 Music              388     0.200013
# ..   ...       ...                   ...              ...          ...
# 34  2021  Positive                Person            13507     7.757828
# 35  2021  Positive             Political              564     0.323937
# 36  2021  Positive                 Sport             4250     2.441014
# 37  2021  Positive         TV and Movies            18928    10.871413
# 38  2021  Positive            Video Game             1015     0.582971
#
#     % with retweets  % with likes  retweets mean  likes mean
# 0             15.91         47.73           0.25        1.86
# 1             15.71         49.78           0.64        3.09
# 2             15.46         50.11           0.58        3.62
# 3             14.26         44.95           0.42        2.84
# 4             19.07         49.74           0.52        3.17
# ..              ...           ...            ...         ...
# 34            17.54         52.06           0.63        5.02
# 35            23.94         51.06           1.41        6.21
# 36            27.13         69.20           0.80        8.21
# 37            17.23         58.05           0.52        6.30
# 38            15.96         63.25           0.49        6.43
#
# [112 rows x 9 columns]

# %%
multi_label_chart_v2(df_analysis, 'year', sentiments, "sentiment", '% with retweets', "Sentiment", "% with retweets", "topics_cleaned", 5, "group", 0.32, "Tweet sentiment by topic and corresponding % retweet count", offline_graphs)
# Out:
# <div>                            <div id="9e384dda-9484-4ae5-a0ae-8fd437cebcd6" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e384dda-9484-4ae5-a0ae-8fd437cebcd6")) {                    Plotly.newPlot(                        "9e384dda-9484-4ae5-a0ae-8fd437cebcd6",                        [{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Book<br>sentiment=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":true,"text":[15.91,28.57,31.97],"textposition":"auto","x":["Negative","Neutral","Positive"],"xaxis":"x11","y":[15.91,28.57,31.97],"yaxis":"y11","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Brand<br>sentiment=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[15.71,13.5,18.36],"textposition":"auto","x":["Negative","Neutral","Positive"],"xaxis":"x12","y":[15.71,13.5,18.36],"yaxis":"y12","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Entities<br>sentiment=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[15.46,13.89,15.77],"textposition":"auto","x":["Negative","Neutral","Positive"],"xaxis":"x13","y":[15.46,13.89,15.77],"yaxis":"y13","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Interest and Hobbies<br>sentiment=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[14.26,13.23,19.4],"textposition":"auto","x":["Negative","Neutral","Positive"],"xaxis":"x14","y":[14.26,13.23,19.4],"yaxis":"y14","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Music<br>sentiment=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[19.07,20.0,18.17],"textposition":"auto","x":["Negative","Neutral","Positive"],"xaxis":"x15","y":[19.07,20.0,18.17],"yaxis":"y15","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Other<br>sentiment=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[15.9,12.64,16.94],"textposition":"auto","x":["Negative","Neutral","Positive"],"xaxis":"x6","y":[15.9,12.64,16.94],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Person<br>sentiment=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[15.02,13.61,14.66],"textposition":"auto","x":["Negative","Neutral","Positive"],"xaxis":"x7","y":[15.02,13.61,14.66],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","hovertemplate":"year=2019<br>topics_cleaned=Political<br>sentiment=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"2019","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"2019","offsetgroup":"2019","orientation":"v","showlegend":false,"text":[16.15,13.83,24.39],"textposition":"auto","x":["Negative","Neutral","Positive"],"xaxis":"x8","y":[16.15,13.83,24.39],"yaxis" ...

# %%
multi_label_chart(df_analysis, "topics_cleaned", topics_categories, "sentiment", "% with retweets", "sentiment", "% with retweets", "Tweet sentiment by topic and corresponding % retweet count", offline_graphs)
# Out:
# <div>                            <div id="701be748-9d50-494a-a2f9-212f2d1962ce" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("701be748-9d50-494a-a2f9-212f2d1962ce")) {                    Plotly.newPlot(                        "701be748-9d50-494a-a2f9-212f2d1962ce",                        [{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Book<br>year=2019<br>sentiment=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Book","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"Book","offsetgroup":"Book","orientation":"v","showlegend":true,"text":[15.91,28.57,31.97],"textposition":"auto","x":["Negative","Neutral","Positive"],"xaxis":"x","y":[15.91,28.57,31.97],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Book<br>year=2020<br>sentiment=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Book","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"Book","offsetgroup":"Book","orientation":"v","showlegend":false,"text":[7.41,11.36,20.63],"textposition":"auto","x":["Negative","Neutral","Positive"],"xaxis":"x2","y":[7.41,11.36,20.63],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Book<br>year=2021<br>sentiment=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Book","marker":{"color":"#006D77","pattern":{"shape":""}},"name":"Book","offsetgroup":"Book","orientation":"v","showlegend":false,"text":[11.29,12.36,22.16],"textposition":"auto","x":["Negative","Neutral","Positive"],"xaxis":"x3","y":[11.29,12.36,22.16],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Brand<br>year=2019<br>sentiment=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Brand","marker":{"color":"#FBD1A2","pattern":{"shape":""}},"name":"Brand","offsetgroup":"Brand","orientation":"v","showlegend":true,"text":[15.71,13.5,18.36],"textposition":"auto","x":["Negative","Neutral","Positive"],"xaxis":"x","y":[15.71,13.5,18.36],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Brand<br>year=2020<br>sentiment=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Brand","marker":{"color":"#FBD1A2","pattern":{"shape":""}},"name":"Brand","offsetgroup":"Brand","orientation":"v","showlegend":false,"text":[14.6,13.58,16.98],"textposition":"auto","x":["Negative","Neutral","Positive"],"xaxis":"x2","y":[14.6,13.58,16.98],"yaxis":"y2","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Brand<br>year=2021<br>sentiment=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Brand","marker":{"color":"#FBD1A2","pattern":{"shape":""}},"name":"Brand","offsetgroup":"Brand","orientation":"v","showlegend":false,"text":[14.66,13.02,19.01],"textposition":"auto","x":["Negative","Neutral","Positive"],"xaxis":"x3","y":[14.66,13.02,19.01],"yaxis":"y3","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Entities<br>year=2019<br>sentiment=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Entities","marker":{"color":"#7DCFB6","pattern":{"shape":""}},"name":"Entities","offsetgroup":"Entities","orientation":"v","showlegend":true,"text":[15.46,13.89,15.77],"textposition":"auto","x":["Negative","Neutral","Positive"],"xaxis":"x","y":[15.46,13.89,15.77],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"topics_cleaned=Entities<br>year=2020<br>sentiment=%{x}<br>% with retweets=%{text}<extra></extra>","legendgroup":"Entities","marker":{"color":"#7DCFB6","pattern":{"shape":""}},"name":"Entities","offsetgroup":"Entities","orientation":"v","showlegend":false,"text":[12.92,12.95,15.74],"textposition":"auto","x":["Negative","Neutral","Positive"],"xaxis":"x2","y":[12.92,12.95,15.74],"yaxis":" ...

# %% [markdown]
# ## Case study: Covid-19

# %%
tweets_2020, tweets_2020_covid = get_covid_datasets(tweet_analysis)

# %%
df_analysis = retweets_likes_info_by_year(tweets_2020, ['month'], months)
analysis_chart(df_analysis, 'month', 'retweets mean', 'likes mean', 'Meses', 'Média de retweets',
               'Média de gostos', 'Média de retweets e gostos durante o ano de 2020', offline_graphs)

# %%
df_analysis = retweets_likes_info_by_year(tweets_2020_covid, ['month'], months)
analysis_chart(df_analysis, 'month', 'retweets mean', 'likes mean', 'Meses', 'Média de retweets',
               'Média de gostos', 'Média de retweets e gostos em tweets sobre covid durante o ano de 2020',
               offline_graphs)

# %%
df_analysis = retweets_likes_info_by_year(tweets_2020, ['sentiment'], sentiments)
analysis_chart(df_analysis, 'sentiment', 'retweets mean', 'likes mean', 'Sentimentos', 'Média de retweets',
               'Média de gostos', 'Média de retweets e likes por sentimento em 2020', offline_graphs)

# %%
df_analysis = retweets_likes_info_by_year(tweets_2020_covid, ['sentiment'], sentiments)
analysis_chart(df_analysis, 'sentiment', 'retweets mean', 'likes mean', 'Sentimentos', 'Média de retweets',
               'Média de gostos', 'Média de retweets e likes por sentimento em tweets sobre covid em 2020',
               offline_graphs)

# %%
test_2020 = tweet_analysis[tweet_analysis['year'] == 2020].copy()
test_2021 = tweet_analysis[tweet_analysis['year'] == 2021].copy()

# %%
covid_keywords = ['Coronavirus', 'Corona', 'CDC', 'Ncov', 'Wuhan', 'Outbreak', 'China', 'Koronavirus', 'Wuhancoronavirus', 'Wuhanlockdown', 'N95', 'Kungflu', 'Epidemic', 'Sinophobia', 'Covid-19', 'Corona virus', 'Covid19', 'Sars-cov-2', 'COVID–19', 'COVD', 'Pandemic', 'Coronapocalypse', 'CancelEverything', 'Coronials', 'SocialDistancing', 'Panic buying', 'DuringMy14DayQuarantine', 'Panic shopping', 'InMyQuarantineSurvivalKit', 'chinese virus', 'stayhomechallenge', 'DontBeASpreader', 'lockdown', 'shelteringinplace', 'staysafestayhome', 'trumppandemic', 'flatten the curve', 'GetMePPE', 'covidiot', 'epitwitter', 'Pandemie']

# %%
def find_keywords_in_tweets(keywords, tweets):
    res = []
    for text in tweets:
        tweet_words = text.split(' ')
        intersections = [i for i in tweet_words if i in keywords]
        if len(intersections) > 0:
           res.append(1)
        else:
            res.append(0)
    return res

# %%
test_2020['covid_matches'] = find_keywords_in_tweets(covid_keywords, test_2020['text'])
test_2021['covid_matches'] = find_keywords_in_tweets(covid_keywords, test_2021['text'])
# Out:
# /var/folders/7r/g2lhjv3x7bb_lgcnhj7_q9hr0000gn/T/ipykernel_16516/1311236048.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/7r/g2lhjv3x7bb_lgcnhj7_q9hr0000gn/T/ipykernel_16516/1311236048.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test_2020_covid = test_2020[test_2020['covid_matches'] == 1]
test_2021_covid = test_2021[test_2021['covid_matches'] == 1]

# %%
print(test_2020_covid.shape[0])
print(test_2021_covid.shape[0])
# Out:
# 1422
# 605

# %%
test_2020_covid['month'].value_counts(normalize=True, sort=False)
# Out:
# January      0.020394
# February     0.036568
# March        0.287623
# April        0.155415
# May          0.113221
# June         0.073840
# July         0.079466
# August       0.046414
# September    0.059072
# October      0.045007
# November     0.037271
# December     0.045710
# Name: month, dtype: float64

# %%
test_2021_covid['month'].value_counts(normalize=True, sort=False)
# Out:
# January      0.105785
# February     0.084298
# March        0.074380
# April        0.082645
# May          0.112397
# June         0.046281
# July         0.094215
# August       0.090909
# September    0.047934
# October      0.056198
# November     0.059504
# December     0.145455
# Name: month, dtype: float64

# %%
df_analysis = retweets_likes_info_by_year(test_2020, ['month'], months)
df_analysis
# Out:
#     year      month  count month   % month  % with retweets  % with likes  \
# 0   2020    January        45117  8.492979            17.50         50.44
# 1   2020   February        42280  7.958933            18.08         50.98
# 2   2020      March        45167  8.502392            17.67         51.43
# 3   2020      April        43725  8.230945            16.83         50.54
# 4   2020        May        45038  8.478108            16.90         50.39
# 5   2020       June        43479  8.184637            17.64         48.52
# 6   2020       July        44979  8.467002            16.48         48.59
# 7   2020     August        44893  8.450813            15.92         48.06
# 8   2020  September        43503  8.189155            15.60         46.81
# 9   2020    October        44961  8.463613            15.34         46.91
# 10  2020   November        43411  8.171836            13.43         47.60
# 11  2020   December        44674  8.409588            13.09         47.06
#
#     retweets mean  likes mean
# 0            0.55        3.89
# 1            0.57        3.97
# 2            0.55        3.68
# 3            0.49        3.59
# 4            0.52        3.55
# 5            0.59        3.72
# 6            0.52        3.63
# 7            0.47        3.47
# 8            0.45        3.38
# 9            0.48        3.48
# 10           0.38        3.39
# 11           0.35        3.31

# %%
analysis_chart(df_analysis, 'month', 'retweets mean', 'likes mean', 'Month', 'Retweets mean', 'Likes mean',
               'Average retweets and likes during the year', offline_graphs)
# Out:
# <div>                            <div id="01327b1f-6c38-414f-9079-644c480db5a6" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01327b1f-6c38-414f-9079-644c480db5a6")) {                    Plotly.newPlot(                        "01327b1f-6c38-414f-9079-644c480db5a6",                        [{"marker":{"color":"#006D77"},"name":"Retweets mean 2020","textposition":"inside","width":0.28,"x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[0.55,0.57,0.55,0.49,0.52,0.59,0.52,0.47,0.45,0.48,0.38,0.35],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#FBD1A2"},"name":"Likes mean 2020","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[3.89,3.97,3.68,3.59,3.55,3.72,3.63,3.47,3.38,3.48,3.39,3.31],"type":"scatter","xaxis":"x","yaxis":"y2"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parco ...

# %%
df_analysis = retweets_likes_info_by_year(test_2020_covid, ['month'], months)
df_analysis
# Out:
#     year      month  count month    % month  % with retweets  % with likes  \
# 0   2020    January           29   2.039381            31.03         51.72
# 1   2020   February           52   3.656821            25.00         53.85
# 2   2020      March          409  28.762307            22.98         52.08
# 3   2020      April          221  15.541491            20.81         45.25
# 4   2020        May          161  11.322082            19.88         45.34
# 5   2020       June          105   7.383966            14.29         38.10
# 6   2020       July          113   7.946554            23.01         46.02
# 7   2020     August           66   4.641350            15.15         43.94
# 8   2020  September           84   5.907173            21.43         33.33
# 9   2020    October           64   4.500703            17.19         35.94
# 10  2020   November           53   3.727145            13.21         50.94
# 11  2020   December           65   4.571027            12.31         35.38
#
#     retweets mean  likes mean
# 0            0.38        1.62
# 1            0.94        2.62
# 2            0.79        3.93
# 3            0.73        3.00
# 4            0.82        3.39
# 5            0.30        1.19
# 6            0.50        1.35
# 7            0.27        1.71
# 8            1.35        3.40
# 9            0.23        1.31
# 10           0.21        2.32
# 11           0.20        2.29

# %%
analysis_chart(df_analysis, 'month', 'retweets mean', 'likes mean', 'Month', 'Retweets mean', 'Likes mean',
               'Average retweets and likes during the year', offline_graphs)
# Out:
# <div>                            <div id="b6402b2d-44b5-4170-8403-bba45f1fe1ea" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6402b2d-44b5-4170-8403-bba45f1fe1ea")) {                    Plotly.newPlot(                        "b6402b2d-44b5-4170-8403-bba45f1fe1ea",                        [{"marker":{"color":"#006D77"},"name":"Retweets mean 2020","textposition":"inside","width":0.28,"x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[0.38,0.94,0.79,0.73,0.82,0.3,0.5,0.27,1.35,0.23,0.21,0.2],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#FBD1A2"},"name":"Likes mean 2020","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[1.62,2.62,3.93,3.0,3.39,1.19,1.35,1.71,3.4,1.31,2.32,2.29],"type":"scatter","xaxis":"x","yaxis":"y2"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords" ...
